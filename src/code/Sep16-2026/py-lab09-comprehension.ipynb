# %%
def pick(names):
    # return [x.upper() for x in name if len(x) >= 3]
    # result = []
    # for name in names:
    #     if len(name) >= 3:
    #         result.append(name.upper())
    # return result
    return [name.upper() for name in names if len(name) >= 3]

name_list = ["John", "Peter", "Be", "Emily"]
