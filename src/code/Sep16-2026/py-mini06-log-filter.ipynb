# %%
def errors(lines):
    # result = []
    # for x in lines:
    #     if"ERROR" in lines:
    #         result.append(x)
    # return x
    return [x for x in lines if 'ERROR' in x]

def messages(lines):
#     result = []
#     for y in lines:
#         result.append(y.split(" ",3)[3])
    # result = []
    # for line in lines:
    #     msg = " ".join(line.split()[3:]) # 결제" "실패" --> "결제 실패"
    #     result.append(msg)
    # return result

    return [y.split(" ",3)[3] for y in lines]



def summary(lines):
    return messages(errors(lines))



result = []
a = [
    "2026-08-11 09:15 ERROR 결제 실패",
    "2026-08-11 09:16 INFO 사용자 로그인",
    "2026-08-11 09:20 ERROR DB 연결 끊김",
    "2026-08-11 09:31 WARN 응답 지연",
]
# print(a[0])
for i in a:
    if 'ERROR' in i :
        result.append(i)

print(f'result->',result)

result1 = []
for j in a:
    result1.append(j.split(" ",3)[3])

print(result1)

print(

)
