# %%
x = 10
x = x + 5
print(x)
# Out:
# 15

# %%
a = 25
b = 36.5
c = '파이썬'
d = True
print(a,b,c,d)
# Out:
# 25 36.5 파이썬 True

# %%
print(type(25))
print(type(36.5))
print(type('python'))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print('10'+ '5')
print(int('10')+int('5'))
print(10 + 5)
# Out:
# 105
# 15
# 15

# %%
age = 25
print(age >=20 and age < 30)
print(age < 10 or age > 20)
print(not age == 30)
# Out:
# True
# True
# True

# %%
height = 1.75
weight = 68
bmi = weight/(height ** 2)
print(bmi)
print("정상 범위인가?", bmi >= 18.5 and bmi < 23)
# Out:
# 22.20408163265306
# 정상 범위인가? True

# %%
price = 1000
print(price*3)
# Out:
# 3000

# %%
x = int(input())
if abs(x) % 2 == 0:
    print("짝수")
elif abs(x) % 2 >= 0:
    print("odd")
else:
    print("o")
# Out:
# odd

# %%
x = 3
print(id(x))
y = x
print(id(y))
y += 3

print(x,y,id(x),id(y))
# Out:
# 140713916556472
# 140713916556472
# 3 6 140713916556472 140713916556568

# %%
x[0] = 2
print('x',id(x),x[0],'y',id(y),y[0])
y = x
print('x',id(x),x[0],'y',id(y),y[0])
x[0] = 5
print('x',id(x),x[0],'y',id(y),y[0])
# Out:
# x 2378568167040 2 y 2378568167040 2
# x 2378568167040 2 y 2378568167040 2
# x 2378568167040 5 y 2378568167040 5

# %%
age = int(input('type your age: '))
print('after 10 years', age + 10, 'years old')
# Out:
# after 10 years 32 years old

# %%
print(f'after 10 years', int(input())+10, 'years old')
print(f'after 10 years', {int(input())+10}, 'years old')
print(f'after 10 years, {int(input())+10} years old')
# Out:
# after 10 years 20 years old
# after 10 years {30} years old
# after 10 years 40 years old

# %%
name = input("what is your name? : ")
print('welcome, ' + name + "!")
# Out:
# welcome, james!

# %%
name=input()
print(f"""welcome
 {name}!""")
# Out:
# welcome
#  dds!

# %%
print(f'welcome {input()}!')
# Out:
# welcome james!

# %%
a = '작은따옴표'
b = "큰따옴표 안엔 '작은' 것도 넣을 수 있어요"
c = """여러 줄도
한 번에 
가능합니다."""
print(a,"\n",b,"\n",c)
print('______________________')
print(a,b,c, sep="\n")
print('______________________')
print(f'{a}\n{b}\n{c}')
print('______________________')
print(f'{a}\\n{b}') 
print('______________________')
print(fr'{a} \n {b}')
# Out:
# 작은따옴표
#  큰따옴표 안엔 '작은' 것도 넣을 수 있어요
#  여러 줄도
# 한 번에
# 가능합니다.
# ______________________
# 작은따옴표
# 큰따옴표 안엔 '작은' 것도 넣을 수 있어요
# 여러 줄도
# 한 번에
# 가능합니다.
# ______________________
# 작은따옴표
# 큰따옴표 안엔 '작은' 것도 넣을 수 있어요
# 여러 줄도
# 한 번에
# 가능합니다.
# ______________________
# 작은따옴표\n큰따옴표 안엔 '작은' 것도 넣을 수 있어요
# ______________________
# 작은따옴표 \\n 큰따옴표 안엔 '작은' 것도 넣을 수 있어요

# %%
word = 'python'
print(word[0],word[3],word[-2])
s = '123456789'
print(s[3:8])
print(s[:3])
print(s[8:])
print(s[-3:-9:-1])
print(s[-3::-1])
print(s[-3:0:-1])
# Out:
# p h o
# 45678
# 123
# 9
# 765432
# 7654321
# 765432

# %%
name='cutty'
age = 23
hometown = "seoul"
# without f-string
print('my name is '+name+ 'and age is ' + str(age) +' years old. ' + 'My hometown is ' + hometown + "." )
# with f-string
print(f'my name is {name} and age is {str(age)} years old. My hometown is {hometown}')
print("my name is {} and age is {} years old my hometown is {}". format(name,age,hometown))
print("my name is {2} and age is {0} years old my hometown is {1}". format(name,age,hometown))
# Out:
# my name is cuttyand age is 23 years old. My hometown is seoul.
# my name is cutty and age is 23 years old. My hometown is seoul
# my name is cutty and age is 23 years old my hometown isseoul
# my name is seoul and age is cutty years old my hometown is23

# %%
s = "   Hello Python  "
print(len(s))
print(s.strip())
print(s.upper())
print(s.lower())
print(s.replace("Python", "World"))
print('ab-cde-fg'.split("-"))
print("apple banana graphs".split())
print('ab-cde-fg'.replace("-",""))
print("apple banana graphs".replace(" ",""))
# Out:
# 17
# Hello Python
#    HELLO PYTHON
#    hello python
#    Hello World
# ['ab', 'cde', 'fg']
# ['apple', 'banana', 'graphs']
# abcdefg
# applebananagraphs

# %%
name = input('name: ').strip()
year = int(input("birth year(ex:1900): "))
age = 2026-year
print('=' * 20)
print(f'hello, {name}')
print(f'this year of your age is {age}')
print(f'sharaout: {name.upper()}')
# Out:
# ...
# hello, jame
# this year of your age is 126
# sharaout: JAME

# %%
name ="철수"
print(f'안녕 {name}')

print(f'당신은 {input()}을 좋아 하시는 군요')
# Out:
# 안녕 철수
# 당신은 노란색을 좋아 하시는 군요

# %%
age =23
print(f'내년엔 {age+1}살')
name = '철수'
age = 20
print(name +"(" + str(age) + ")")
print(f'{name}({age})')
print("{0}({1})".format(name,age))
# Out:
# 내년엔 24살
# 철수(20)
# 철수(20)
# 철수(20)

# %%
x = 1
print(x, id(x))
x = 2
print(x, id(x))
z = 3 + 4j
print(type(z))
print(z.real, z.imag)
print(abs(z))
# Out:
# 1 140713916556408
# 2 140713916556440
# <class 'complex'>
# 3.0 4.0
# 5.0
