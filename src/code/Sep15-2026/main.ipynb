# %%
def say_hello():
    print("안녕하세요!")
    print("반갑습니다!")

say_hello()
say_hello()
# Out:
# 안녕하세요!
# 반갑습니다!
# 안녕하세요!
# 반갑습니다!

# %%
def greet(name):
    print(f'{name}님, 안녕하세요!')

greet('철수')
greet('영희')

def add(a, b):
    print(f'{a} + {b} = {a+b}')

add(3, 5)
# Out:
# 철수님, 안녕하세요!
# 영희님, 안녕하세요!
# 3 + 5 = 8
