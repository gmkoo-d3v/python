# %%
def to_binary(n):
    """양의 정수를 2진수 문자열로. 접두사 없이."""
    return bin(n)[2:]   
# format(n, 'b')
# binary 'b'     hexadecimal 'x' octal 'o'
# f-string f"{n:b} {n:x} {n:o}"
def from_hex(text):
    """16진수 문자열을 정수로."""
    return int(text, 16)


def is_exactly(a, b):
    """두 실수가 정확히 같은가. 이 함수는 '왜 이러면 안 되는지'를 보여준다."""
    return a == b


def is_close_enough(a, b, digits=9):
    """소수 digits 자리까지 반올림해 비교한다."""
    return round(a, digits) == round(b, digits)


def split_seconds(total):
    """초를 (시, 분, 초) 로. divmod 를 쓰면 두 줄이다."""
    
    hours, remain = divmod(total, 3600)
    minutes, seconds = divmod(remain, 60)
    return hours, minutes, seconds

# %%
def to_binary(n):
    """양의 정수를 2진수 문자열로. 접두사 없이."""
    return bin(n)[2:]


def from_hex(text):
    """16진수 문자열을 정수로."""
    return int(text, 16)


def is_exactly(a, b):
    """두 실수가 정확히 같은가. 이 함수는 '왜 이러면 안 되는지'를 보여준다."""
    return a == b


def is_close_enough(a, b, digits=9):
    """소수 digits 자리까지 반올림해 비교한다."""
    return round(a, digits) == round(b, digits)


def split_seconds(total):
    """초를 (시, 분, 초) 로. divmod 를 쓰면 두 줄이다."""
    hours, remain = divmod(total, 3600)
    minutes, seconds = divmod(remain, 60)
    return hours, minutes, seconds
