# %%
is_rain = False
if is_rain:
    print('우산챙기세요')
print("외출합니다.")
# Out:
# 외출합니다.

# %%
score = 85
if score >= 60:
    print("합격!")
    print('축하합니다')
print('확인 끝')
# Out:
# 합격!
# 축하합니다
# 확인 끝

# %%
score = 85
if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'b'
elif score >= 70:
    grade = 'c'
else:
    grade = 'f'
print(f"점수 {score} -> 학점 {grade.upper()}")
# Out:
# 점수 85 -> 학점 B

# %%
score = 10
if score < 70:
    grade = 'f'
elif score < 80:
    grade = 'c'
elif score < 90:
    grade = 'b'
else:
    grade = 'a'
print(f"점수 {score} -> 학점 {grade.upper()}")
# Out:
# 점수 10 -> 학점 F
