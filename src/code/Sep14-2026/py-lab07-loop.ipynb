# %%
# sales 가 주어집니다. 직접 시험해보려면 아래 줄의 # 을 지우세요.
# sales = [45000, 120000, 98000, 150000]

total = 0
big_days = 0
best = 0

for amount in sales:
    total += amount
    best = amount
    if amount >= 100000:
        big_days += 1
        
    if amount > best:
        best = amount

# %%
sales = [45000, 120000, 98000, 150000]
total = 0
big_days = 0
best = 0
worst = 99999999999
for amount in sales:
    total += amount
    if amount >= 100000:
        big_days += 1
        
    if amount > best:
        best = amount

    if amount < worst:
        worst = amount

print(total,big_days, best, worst)
# Out:
# 413000 2 150000 45000
